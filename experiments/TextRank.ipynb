# %%
import pandas as pd
import numpy as np
import gensim as gs
from nltk.tokenize import WordPunctTokenizer
from pymystem3 import Mystem
import networkx as nx
from gensim import models

# %%
w2v = models.Word2Vec.load_word2vec_format(
            'ruscorpora_mean_hs.model.bin'
            , binary=True
            , encoding='utf-8'
        )

# %%
text = open('exi_stemmed.txt' , 'r').read()

tokens = WordPunctTokenizer().tokenize(text)

# %%
def part_of_speech_filter(word):
    tag_pos = word.find('_') + 1
    if tag_pos == 0:
        return False
    tag = word[tag_pos:]
    return tag == 'S' or tag == 'A' or tag == 'ANUM' or tag == 'APRO' or tag == 'ADV'

# %%
unique_words = list(filter(part_of_speech_filter, set(tokens)))

# %%
gr = nx.Graph()
gr.add_nodes_from(unique_words)

for first in unique_words:
    for second in unique_words:
        try:
            weight=w2v.similarity(first, second)
            if weight > 0.2:
                gr.add_edge(first, second, weight=weight)
        except BaseException as e:
            print(e)
# Out:
# 'его_APRO'
# 'один_APRO'
# 'сам_APRO'
# 'другой_APRO'
# 'такой_APRO'
# 'и_S'
# '_ADV'
# 'который_APRO'
# '_A'
# 'можно_ADV'
# 'свой_APRO'
# 'с_S'
# 'в_S'
# 'более_ADV'
# 'тот_APRO'
# 'либо_APRO'
# 'ж_S'
# '_S'
# 'а_S'
# 'все_ADV'
# 'этот_APRO'
# 'теперь_ADV'
# 'его_APRO'
# 'один_APRO'
# 'сам_APRO'
# 'другой_APRO'
# 'такой_APRO'
# 'и_S'
# '_ADV'
# 'который_APRO'
# '_A'
# 'можно_ADV'
# 'свой_APRO'
# 'с_S'
# 'в_S'
# 'более_ADV'
# 'тот_APRO'
# 'либо_APRO'
# 'ж_S'
# '_S'
# 'а_S'
# 'все_ADV'
# 'этот_APRO'
# 'теперь_ADV'
# 'его_APRO'
# 'один_APRO'
# 'сам_APRO'
# 'другой_APRO'
# 'такой_APRO'
# 'и_S'
# '_ADV'
# 'который_APRO'
# '_A'
# 'можно_ADV'
# 'свой_APRO'
# 'с_S'
# 'в_S'
# 'более_ADV'
# 'тот_APRO'
# 'либо_APRO'
# 'ж_S'
# '_S'
# 'а_S'
# 'все_ADV'
# 'этот_APRO'
# 'теперь_ADV'
# 'его_APRO'
# 'один_APRO'
# 'сам_APRO'
# 'другой_APRO'
# 'такой_APRO'
# 'и_S'
# '_ADV'
# 'который_APRO'
# '_A'
# 'можно_ADV'
# 'свой_APRO'
# 'с_S'
# 'в_S'
# 'более_ADV'
# 'тот_APRO'
# 'либо_APRO'
# 'ж_S'
# '_S'
# ...

# %%
calculated_page_rank = nx.pagerank(gr, weight='weight')

# %%
calculated_page_rank
# Out:
# {'_A': 0.0004331504475887959,
#  '_ADV': 0.0004331504475887959,
#  '_S': 0.0004331504475887959,
#  'а_S': 0.0004331504475887959,
#  'австрия_S': 0.0029423947098901316,
#  'айрис_S': 0.00316896078456653,
#  'акцент_S': 0.0013428990085945808,
#  'альбер_S': 0.001803842837402086,
#  'антропология_S': 0.0040916927863375325,
#  'аргентина_S': 0.0023926774688908881,
#  'атеистический_A': 0.0035172802011385678,
#  'барт_S': 0.0025480593936304963,
#  'бездумный_A': 0.001514002939973469,
#  'безысходность_S': 0.0024582072697073281,
#  'бердяев_S': 0.0033982801360419247,
#  'бессильный_A': 0.0015323939685985795,
#  'бесчисленный_A': 0.001469513250651469,
#  'блез_S': 0.0022149067244848237,
#  'близкий_A': 0.0013891636966406023,
#  'более_ADV': 0.0004331504475887959,
#  'большинство_S': 0.0014399427162015881,
#  'большой_A': 0.001783467109201902,
#  'боязнь_S': 0.0026719184260088524,
#  'бытие_S': 0.0069208392333977532,
#  'в_S': 0.0004331504475887959,
#  'век_S': 0.0014647297393646536,
# ...

# %%
for word in tokens:
    print((' ! ' if word in calculated_page_rank and calculated_page_rank[word] > 0.004 else '   ') + word)
# Out:
#  ! экзистенциализм_S
#    фр_
#    ?
#    existentialisme_
#    ?
#    от_PR
#    латы_S
#    existentia_
#    ?
#    существование_S
#    также_ADV
#  ! философия_S
#    существование_S
#    особый_A
#    направление_S
#    в_PR
#  ! философия_S
#    XX_
#    ?
#    век_S
#    акцентировать_V
#    свой_APRO
#    внимание_S
#    на_PR
#    уникальность_S
#  ! бытие_S
#    человек_S
#    провозглашать_V
#    его_APRO
#  ! иррациональный_A
#  ! экзистенциализм_S
#    развиваться_V
#    параллельно_ADV
#    родственный_A
#    направление_S
#  ! персонализм_S
#    и_CONJ
#  ! философский_A
#  ! антропология_S
#    от_PR
#    который_APRO
#    он_SPRO
#    отличаться_V
#    прежде_PR
#    все_SPRO
#  ! идея_S
#    преодоление_S
#    а_CONJ
#    не_PART
#    раскрытие_S
#    человек_S
#    собственный_A
#  ! сущность_S
#    и_CONJ
#    большой_A
#    акцент_S
#    на_PR
#    глубина_S
#    эмоциональный_A
#  ! природа_S
#    в_PR
#    чистый_A
#    вид_S
#  ! экзистенциализм_S
# ...

# %%
print(gr.get_edge_data('экзистенциализм_S', 'иррациональный_A'))
# Out:
# {'weight': 0.31294335575349624}

# %%
from summa import keywords
text = """экзистенциализм фр?? existentialisme?? от латы existentia?? существование также философия существование особый направление в философия XX?? век акцентировать свой внимание на уникальность бытие человек провозглашать его иррациональный экзистенциализм развиваться параллельно родственный направление персонализм и философский антропология от который он отличаться прежде все идея преодоление а не раскрытие человек собственный сущность и большой акцент на глубина эмоциональный природа в чистый вид экзистенциализм как философский направление никогда не существовать источник не указывать день противоречивость этот термин исходить из самый содержание экзистенция? так как она по определение индивидуальный и неповторимый означать переживание отдельно взять индивид не похожий ни на кто источник не указывать день этот противоречивость являться причина то что практически никто из мыслитель причислять к экзистенциализм не быть в действительность философ экзистенциалист единственный кто четко выражать свой принадлежность к этот направление быть жан-поль сартр его позиция быть обозначать в доклад экзистенциализм это гуманизм где он и предпринимать попытка обобщать экзистенциалистский устремление отдельный мыслитель начало XX?? век согласно экзистенциальный психолог и психотерапевт р Мэю?? экзистенциализм не просто философский направление а скоро культурный движение запечатлевать глубокий